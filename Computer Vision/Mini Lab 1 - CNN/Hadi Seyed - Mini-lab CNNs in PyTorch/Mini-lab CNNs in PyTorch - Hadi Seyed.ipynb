# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F


from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([transforms.ToTensor(),
                                transforms.RandomCrop((256,256),pad_if_needed=True),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.OxfordIIITPet("pets_data/","trainval",transform=transform,download=True)
test_dataset = torchvision.datasets.OxfordIIITPet("pets_data/","test",transform=transform,download=True)

train_loader = DataLoader(train_dataset,batch_size=8)
test_loader = DataLoader(test_dataset,batch_size=8)

##### This network design is too shallow for the task, your job is to make it deeper! #####

class MyNetwork(nn.Module):
    def __init__(self):
        super(MyNetwork, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5, padding=2)  # 5x5 convolution
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)  # 3x3 convolution
        self.pool1 = nn.MaxPool2d(2, 2)  # 2x2 MaxPool
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)  # 3x3 convolution
        self.conv4 = nn.Conv2d(256, 256, 3, padding=1)  # 3x3 convolution
        self.pool2 = nn.MaxPool2d(2, 2)  # 2x2 MaxPool
        self.conv5 = nn.Conv2d(256, 512, 3, padding=1)  # 3x3 convolution
        self.pool3 = nn.MaxPool2d(2, 2)  # 2x2 MaxPool
        self.conv6 = nn.Conv2d(512, 512, 3, padding=1)  # 3x3 convolution
        self.fc1 = nn.Linear(512 * 32 * 32, 37)  # Linear layer with the final image size (32x32 here)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.pool2(x)
        x = F.relu(self.conv5(x))
        x = self.pool3(x)
        x = F.relu(self.conv6(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor for the linear layer
        x = self.fc1(x)
        return x

#######################


model = MyNetwork()

##### Training Loop #####

learning_rate = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loss_func = torch.nn.CrossEntropyLoss()

num_epochs = 5

for epoch in range(num_epochs):
    print("Epoch:", epoch)
    for im, label, in train_loader:

        optimizer.zero_grad()

        output = model(im)
        loss = loss_func(output,label)
        print(loss)

        loss.backward()
        optimizer.step()


##### Testing Loop #####

correct = 0; total=0

model.eval()
with torch.no_grad():
    for im,label in test_loader:
        
        output = model(im)
        guess = torch.argmax(output,dim=1)
        
        correct += torch.sum(guess == label).item()
        total += len(guess)

print("Testing Accuracy is", correct/total * 100, "%")
# Out:
# Epoch: 0
# tensor(3.6092, grad_fn=<NllLossBackward0>)
# tensor(3.1357, grad_fn=<NllLossBackward0>)
# tensor(2.2898, grad_fn=<NllLossBackward0>)
# tensor(1.0055, grad_fn=<NllLossBackward0>)
# tensor(0.1435, grad_fn=<NllLossBackward0>)
# tensor(0.0016, grad_fn=<NllLossBackward0>)
# tensor(16.3195, grad_fn=<NllLossBackward0>)
# tensor(16.3047, grad_fn=<NllLossBackward0>)
# tensor(10.2583, grad_fn=<NllLossBackward0>)
# tensor(5.7461, grad_fn=<NllLossBackward0>)
# tensor(3.7069, grad_fn=<NllLossBackward0>)
# tensor(2.4582, grad_fn=<NllLossBackward0>)
# tensor(3.2171, grad_fn=<NllLossBackward0>)
# tensor(3.8768, grad_fn=<NllLossBackward0>)
# tensor(3.5339, grad_fn=<NllLossBackward0>)
# tensor(3.2894, grad_fn=<NllLossBackward0>)
# tensor(3.1029, grad_fn=<NllLossBackward0>)
# tensor(2.9499, grad_fn=<NllLossBackward0>)
# tensor(3.0718, grad_fn=<NllLossBackward0>)
# tensor(3.7564, grad_fn=<NllLossBackward0>)
# tensor(3.6223, grad_fn=<NllLossBackward0>)
# tensor(3.4818, grad_fn=<NllLossBackward0>)
# tensor(3.3430, grad_fn=<NllLossBackward0>)
# tensor(3.2078, grad_fn=<NllLossBackward0>)
# tensor(3.0705, grad_fn=<NllLossBackward0>)
# tensor(3.9187, grad_fn=<NllLossBackward0>)
# tensor(3.8130, grad_fn=<NllLossBackward0>)
# tensor(3.6846, grad_fn=<NllLossBackward0>)
# tensor(3.5505, grad_fn=<NllLossBackward0>)
# tensor(3.4211, grad_fn=<NllLossBackward0>)
# tensor(3.2943, grad_fn=<NllLossBackward0>)
# tensor(3.7085, grad_fn=<NllLossBackward0>)
# tensor(3.7909, grad_fn=<NllLossBackward0>)
# tensor(3.6757, grad_fn=<NllLossBackward0>)
# tensor(3.5573, grad_fn=<NllLossBackward0>)
# tensor(3.4397, grad_fn=<NllLossBackward0>)
# tensor(3.3192, grad_fn=<NllLossBackward0>)
# tensor(3.5283, grad_fn=<NllLossBackward0>)
# tensor(3.7890, grad_fn=<NllLossBackward0>)
# tensor(3.6895, grad_fn=<NllLossBackward0>)
# tensor(3.5800, grad_fn=<NllLossBackward0>)
# tensor(3.4658, grad_fn=<NllLossBackward0>)
# tensor(3.3493, grad_fn=<NllLossBackward0>)
# tensor(3.4065, grad_fn=<NllLossBackward0>)
# tensor(3.8827, grad_fn=<NllLossBackward0>)
# tensor(3.7670, grad_fn=<NllLossBackward0>)
# tensor(3.6566, grad_fn=<NllLossBackward0>)
# tensor(3.5400, grad_fn=<NllLossBackward0>)
# tensor(3.4323, grad_fn=<NllLossBackward0>)
# tensor(3.4050, grad_fn=<NllLossBackward0>)
# tensor(3.8428, grad_fn=<NllLossBackward0>)
# tensor(3.7474, grad_fn=<NllLossBackward0>)
# tensor(3.6528, grad_fn=<NllLossBackward0>)
# tensor(3.5666, grad_fn=<NllLossBackward0>)
# tensor(3.4934, grad_fn=<NllLossBackward0>)
# tensor(3.4254, grad_fn=<NllLossBackward0>)
# tensor(3.7419, grad_fn=<NllLossBackward0>)
# tensor(3.7454, grad_fn=<NllLossBackward0>)
# tensor(3.6874, grad_fn=<NllLossBackward0>)
# tensor(3.6284, grad_fn=<NllLossBackward0>)
# tensor(3.5741, grad_fn=<NllLossBackward0>)
# tensor(3.5239, grad_fn=<NllLossBackward0>)
# tensor(3.6653, grad_fn=<NllLossBackward0>)
# tensor(3.7425, grad_fn=<NllLossBackward0>)
# tensor(3.6958, grad_fn=<NllLossBackward0>)
# tensor(3.6499, grad_fn=<NllLossBackward0>)
# tensor(3.6075, grad_fn=<NllLossBackward0>)
# tensor(3.5695, grad_fn=<NllLossBackward0>)
# tensor(3.6124, grad_fn=<NllLossBackward0>)
# tensor(3.7123, grad_fn=<NllLossBackward0>)
# tensor(3.6817, grad_fn=<NllLossBackward0>)
# tensor(3.6479, grad_fn=<NllLossBackward0>)
# tensor(3.6212, grad_fn=<NllLossBackward0>)
# tensor(3.5960, grad_fn=<NllLossBackward0>)
# tensor(3.6375, grad_fn=<NllLossBackward0>)
# tensor(3.6843, grad_fn=<NllLossBackward0>)
# tensor(3.6598, grad_fn=<NllLossBackward0>)
# tensor(3.6347, grad_fn=<NllLossBackward0>)
# tensor(3.6064, grad_fn=<NllLossBackward0>)
# tensor(3.5741, grad_fn=<NllLossBackward0>)
# tensor(3.5758, grad_fn=<NllLossBackward0>)
# tensor(3.6591, grad_fn=<NllLossBackward0>)
# tensor(3.6305, grad_fn=<NllLossBackward0>)
# tensor(3.5986, grad_fn=<NllLossBackward0>)
# tensor(3.5485, grad_fn=<NllLossBackward0>)
# tensor(3.4932, grad_fn=<NllLossBackward0>)
# tensor(3.3994, grad_fn=<NllLossBackward0>)
# tensor(3.6947, grad_fn=<NllLossBackward0>)
# tensor(3.6357, grad_fn=<NllLossBackward0>)
# tensor(3.5445, grad_fn=<NllLossBackward0>)
# tensor(3.4039, grad_fn=<NllLossBackward0>)
# tensor(3.2423, grad_fn=<NllLossBackward0>)
# tensor(2.9581, grad_fn=<NllLossBackward0>)
# tensor(3.5885, grad_fn=<NllLossBackward0>)
# tensor(3.8409, grad_fn=<NllLossBackward0>)
# tensor(3.5980, grad_fn=<NllLossBackward0>)
# tensor(3.3111, grad_fn=<NllLossBackward0>)
# tensor(2.9458, grad_fn=<NllLossBackward0>)
# tensor(2.4735, grad_fn=<NllLossBackward0>)
# tensor(3.3925, grad_fn=<NllLossBackward0>)
# tensor(4.5813, grad_fn=<NllLossBackward0>)
# tensor(3.9683, grad_fn=<NllLossBackward0>)
# tensor(3.4374, grad_fn=<NllLossBackward0>)
# tensor(3.0434, grad_fn=<NllLossBackward0>)
# tensor(2.7329, grad_fn=<NllLossBackward0>)
# tensor(2.8936, grad_fn=<NllLossBackward0>)
# tensor(3.9696, grad_fn=<NllLossBackward0>)
# tensor(3.6999, grad_fn=<NllLossBackward0>)
# tensor(3.4365, grad_fn=<NllLossBackward0>)
# tensor(3.2127, grad_fn=<NllLossBackward0>)
# tensor(2.9466, grad_fn=<NllLossBackward0>)
# tensor(2.7122, grad_fn=<NllLossBackward0>)
# tensor(4.1192, grad_fn=<NllLossBackward0>)
# tensor(3.8690, grad_fn=<NllLossBackward0>)
# tensor(3.6533, grad_fn=<NllLossBackward0>)
# tensor(3.4472, grad_fn=<NllLossBackward0>)
# tensor(3.2589, grad_fn=<NllLossBackward0>)
# tensor(3.0978, grad_fn=<NllLossBackward0>)
# tensor(3.7597, grad_fn=<NllLossBackward0>)
# tensor(3.8377, grad_fn=<NllLossBackward0>)
# tensor(3.6634, grad_fn=<NllLossBackward0>)
# tensor(3.4979, grad_fn=<NllLossBackward0>)
# tensor(3.3676, grad_fn=<NllLossBackward0>)
# tensor(3.2533, grad_fn=<NllLossBackward0>)
# tensor(3.4955, grad_fn=<NllLossBackward0>)
# tensor(3.7480, grad_fn=<NllLossBackward0>)
# tensor(3.6315, grad_fn=<NllLossBackward0>)
# tensor(3.5093, grad_fn=<NllLossBackward0>)
# tensor(3.3764, grad_fn=<NllLossBackward0>)
# tensor(3.2463, grad_fn=<NllLossBackward0>)
# tensor(3.2980, grad_fn=<NllLossBackward0>)
# tensor(3.8208, grad_fn=<NllLossBackward0>)
# tensor(3.7128, grad_fn=<NllLossBackward0>)
# tensor(3.5734, grad_fn=<NllLossBackward0>)
# tensor(3.4175, grad_fn=<NllLossBackward0>)
# tensor(3.2501, grad_fn=<NllLossBackward0>)
# tensor(3.0795, grad_fn=<NllLossBackward0>)
# tensor(4.0720, grad_fn=<NllLossBackward0>)
# tensor(3.9320, grad_fn=<NllLossBackward0>)
# tensor(3.7514, grad_fn=<NllLossBackward0>)
# tensor(3.5750, grad_fn=<NllLossBackward0>)
# tensor(3.4255, grad_fn=<NllLossBackward0>)
# tensor(3.2934, grad_fn=<NllLossBackward0>)
# tensor(3.7178, grad_fn=<NllLossBackward0>)
# tensor(3.7794, grad_fn=<NllLossBackward0>)
# tensor(3.6470, grad_fn=<NllLossBackward0>)
# tensor(3.5296, grad_fn=<NllLossBackward0>)
